# %% [markdown]
# import pandas as pd
# import requests
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
url_product = "https://fakestoreapi.com/products"
response = requests.get(url_product)
data = response.json()

# %%
product_pd = pd.DataFrame(data)
product_pd.head(5)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# ...

# %%
analysis_table = product_pd[["id", "title", "price", "category"]]
analysis_table.head(5)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#          category
# 0  men's clothing
# 1  men's clothing
# 2  men's clothing
# 3  men's clothing
# 4        jewelery

# %%
media_category = analysis_table.groupby("category")["price"].mean()
media_category
# Out:
# category
# electronics         332.498333
# jewelery            220.995000
# men's clothing       51.057500
# women's clothing     26.286667
# Name: price, dtype: float64

# %%
clothing_category = analysis_table[analysis_table["title"].str.contains("jacket",case=False)]
clothing_category
# Out:
#     id                                              title  price  \
# 2    3                                 Mens Cotton Jacket  55.99
# 14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...  56.99
# 15  16  Lock and Love Women's Removable Hooded Faux Le...  29.95
# 16  17  Rain Jacket Women Windbreaker Striped Climbing...  39.99
#
#             category
# 2     men's clothing
# 14  women's clothing
# 15  women's clothing
# 16  women's clothing

# %%
media_clothing_category = clothing_category["price"].mean().round(2)
media_clothing_category
# Out:
# np.float64(45.73)

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(x=media_category.index, y=media_category.values,hue=media_category.index, palette="mako")
for container in ax.containers:
    ax.bar_label(container, fmt='$%.2f', fontsize=12, fontweight="bold")
plt.title("Preço medio por categoria de produto", fontsize=16, fontweight="bold")
plt.xlabel("Categoria/Departamento", fontsize=12)
plt.ylabel("Preço Medio ($)", fontsize=12)
plt.show()

# %%
media_category.to_csv("relatorio_preco_medio.csv")

print("Relatório salvo com sucesso em CSV! 📄✨")
# Out:
# Relatório salvo com sucesso em CSV! 📄✨
